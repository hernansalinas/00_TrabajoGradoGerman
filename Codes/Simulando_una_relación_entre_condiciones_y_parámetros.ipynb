# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Constantes
A, B, C = 4.2, 5.5, 10.2
D, Ea, R, F, n = 0.2, 50.0, 8.314, 0.1, 2.0
k_min, k_max = 0.055, 0.17  # Restricción de k

# Función del modelo pseudo-segundo orden
def modelo_pseudo_n(t, qe, k):
    return qe * (1 - np.exp(- k * t))

# Cálculo de qe basado en C0 y pH
def calcular_qe(C0, pH):
    return A * C0 + B * pH + C

# Cálculo de k con restricción
def calcular_k(T, pH, C0):
    k = D * np.exp(-Ea / (R * T)) * (1 + F * pH) * C0**n
    return np.clip(k, k_min, k_max)  # Limitar k dentro del rango deseado

# Crear un array de tiempo y configurar el número de curvas
time_array = np.array([0,1,3,6,9,12,20,40,60])
n_curvas = 200

# Crear la figura
plt.figure(figsize=(10, 6))

q_ts = []
C0s = []
pHs = []
Ts = []


# Generar y graficar n_curvas
for i in range(n_curvas):
    C0 = np.random.uniform(0.001, 0.87)
    pH = np.random.uniform(2, 10)
    T = np.random.uniform(291.15, 303.15)

    qe = calcular_qe(C0, pH)
    k = calcular_k(T, pH, C0)
    q_t = modelo_pseudo_n(time_array, qe, k)

    # Agregar ruido gaussiano a partir del segundo elemento
    noise = np.random.normal(0, 1.3, size=len(q_t))
    q_t[1:] = q_t[1:] + noise[1:]


    q_ts.append(q_t)
    C0s.append(C0)
    pHs.append(pH)
    Ts.append(T)

    # Graficar cada curva
    plt.plot(time_array, q_t)


# Configuración del gráfico
plt.xlabel('Tiempo')
plt.ylabel('q_t')
plt.title('Gráfico de n curvas q_t con k restringido y ruido gaussiano')
plt.grid(True)
plt.show()

# %%
data = {'q_t' : q_ts , 'C0': C0s, 'pH': pHs, 'T':Ts }
df_data = pd.DataFrame(data)
df_data
# Out:
#                                                    q_t        C0        pH  \
# 0    [0.0, 0.7006873997287548, 9.04391344888484, 14...  0.446373  6.930254
# 1    [0.0, 3.4983033452136327, 8.92227815755451, 17...  0.738497  3.040603
# 2    [0.0, -1.4992441216762833, 7.090115653507504, ...  0.130493  6.152651
# 3    [0.0, 2.2290692589485515, 10.294255809337217, ...  0.653966  3.685389
# 4    [0.0, 1.7359125431019014, 8.494461303675342, 1...  0.126445  9.165358
# ..                                                 ...       ...       ...
# 195  [0.0, 6.437749285144495, 15.503279254378427, 2...  0.734891  4.965255
# 196  [0.0, 4.204494950954812, 11.74884411018705, 23...  0.538519  7.322896
# 197  [0.0, 3.8352216688881287, 8.28038472076072, 15...  0.026476  8.208648
# 198  [0.0, 1.1162214844635363, 5.8876419079621245, ...  0.184068  4.855999
# 199  [0.0, 1.9253089873930276, 4.304581726392043, 8...  0.044320  4.572075
#
#               T
# 0    292.163823
# 1    293.972513
# 2    293.774375
# 3    301.254942
# 4    292.757935
# ..          ...
# 195  301.418084
# 196  292.348487
# 197  294.966215
# 198  300.092918
# 199  292.994779
#
# [200 rows x 4 columns]

# %%
# Seleccionar un índice aleatorio para mostrar una curva
indice_a_mostrar = np.random.randint(0, len(df_data))

# Obtener los datos correspondientes al índice seleccionado
q_t_seleccionado = df_data['q_t'][indice_a_mostrar]
C0_seleccionado = df_data['C0'][indice_a_mostrar]
pH_seleccionado = df_data['pH'][indice_a_mostrar]
T_seleccionado = df_data['T'][indice_a_mostrar]

# Graficar la curva seleccionada
plt.figure(figsize=(10, 6))
plt.plot(time_array, q_t_seleccionado, marker='o', linestyle='-')  # Agrega marcadores y línea continua

# Agregar etiquetas y título al gráfico
plt.xlabel('Tiempo')
plt.ylabel('q_t')
plt.title(f'Curva q_t seleccionada (Índice: {indice_a_mostrar})')
plt.grid(True)

# Mostrar los valores correspondientes de C0, pH y T
plt.text(0.05, 0.95, f'C0: {C0_seleccionado:.3f}\npH: {pH_seleccionado:.3f}\nT: {T_seleccionado:.3f}',
         transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))


plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import models, layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer

# %%
df_data[['C0', 'pH', 'T']]
# Out:
#            C0        pH           T
# 0    0.446373  6.930254  292.163823
# 1    0.738497  3.040603  293.972513
# 2    0.130493  6.152651  293.774375
# 3    0.653966  3.685389  301.254942
# 4    0.126445  9.165358  292.757935
# ..        ...       ...         ...
# 195  0.734891  4.965255  301.418084
# 196  0.538519  7.322896  292.348487
# 197  0.026476  8.208648  294.966215
# 198  0.184068  4.855999  300.092918
# 199  0.044320  4.572075  292.994779
#
# [200 rows x 3 columns]

# %%
#Escalar los datos
scalerX = MinMaxScaler()
X = scalerX.fit_transform(df_data[['C0', 'pH', 'T']])
Y = np.array(df_data['q_t'].tolist())


# transformer = FunctionTransformer(lambda x: x / np.max(x, axis=1, keepdims=True))
# Y_norm = transformer.fit_transform(Y)

Y_norm = Y / np.max(Y)

# %%
plt.figure(figsize=(10, 6))

for i in range(len(Y_norm)):
    plt.plot(time_array, Y_norm[i])

plt.xlabel('Tiempo')
plt.ylabel('Y_norm')
plt.title('Gráfico de todos los valores de Y_norm')
plt.grid(True)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y_norm, test_size=0.2, random_state=42)

# %%
#Definir el modelo
model = models.Sequential([
    layers.Input(shape=(3,)),  # 3 entradas
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(2)
])
#Funciona bastante bien para [16,12] y lr = 0.001

# %%
def modelo_pseudo_n(qe, k):
    t = tf.constant([0, 1, 3, 6, 9, 12, 20, 40, 60], dtype=tf.float32)
    return qe[:, tf.newaxis] * (1 - tf.exp(- k[:, tf.newaxis] * t))

def custom_loss(y_true, y_pred):
    # y_pred tendrá la forma (N, 2), donde cada columna es un parámetro de tu función
    qe = y_pred[:, 0]  # Primer parámetro (qe)
    k = y_pred[:, 1]  # Segundo parámetro (k)

    # Calcula los valores de la función usando los parámetros predichos
    func_value = modelo_pseudo_n(qe, k)


    # Calcula la diferencia entre los valores de la función y los experimentales
    loss = tf.reduce_mean(tf.square(func_value - y_true))
    return loss

def custom_metric(y_true, y_pred):
    # y_pred tiene la forma (N, 2), donde las dos columnas corresponden a los parámetros qe y k
    qe_true = y_true[:, 0]
    k_true = y_true[:, 1]

    qe_pred = y_pred[:, 0]
    k_pred = y_pred[:, 1]

    # Calcula el error relativo (puede ser absoluto o porcentaje)
    qe_error = tf.abs(qe_true - qe_pred)
    k_error = tf.abs(k_true - k_pred)

    # Calcula el error medio
    avg_error = tf.reduce_mean((qe_error + k_error) / 2.0)

    return avg_error

# %%
from tensorflow.keras.optimizers import Adam
learning_rate = 0.001  # Prueba con valores más bajos si quieres un ajuste más fino
optimizer = Adam(learning_rate=learning_rate)


model.compile(optimizer=optimizer, loss=custom_loss, metrics=[custom_metric])

# %%
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - custom_metric: 0.0727 - loss: 40987.3633 - val_custom_metric: 0.0455 - val_loss: 0.1814
# Epoch 2/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.0328 - loss: 0.1710 - val_custom_metric: 0.0329 - val_loss: 0.1901
# Epoch 3/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0352 - loss: 0.1766 - val_custom_metric: 0.0315 - val_loss: 0.1831
# Epoch 4/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.0421 - loss: 0.1801 - val_custom_metric: 0.0350 - val_loss: 0.1754
# Epoch 5/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0481 - loss: 0.1594 - val_custom_metric: 0.0425 - val_loss: 0.1668
# Epoch 6/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0536 - loss: 0.1631 - val_custom_metric: 0.0535 - val_loss: 0.1565
# Epoch 7/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0658 - loss: 0.1467 - val_custom_metric: 0.0669 - val_loss: 0.1461
# Epoch 8/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0785 - loss: 0.1360 - val_custom_metric: 0.0814 - val_loss: 0.1369
# Epoch 9/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.0925 - loss: 0.1245 - val_custom_metric: 0.0954 - val_loss: 0.1307
# Epoch 10/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_metric: 0.1044 - loss: 0.1176 - val_custom_metric: 0.1053 - val_loss: 0.1249
# Epoch 11/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.1152 - loss: 0.1086 - val_custom_metric: 0.1126 - val_loss: 0.1176
# Epoch 12/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.1214 - loss: 0.1169 - val_custom_metric: 0.1191 - val_loss: 0.1095
# Epoch 13/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.1290 - loss: 0.1056 - val_custom_metric: 0.1279 - val_loss: 0.1010
# Epoch 14/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.1391 - loss: 0.0882 - val_custom_metric: 0.1407 - val_loss: 0.0913
# Epoch 15/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.1549 - loss: 0.0832 - val_custom_metric: 0.1574 - val_loss: 0.0790
# Epoch 16/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_metric: 0.1749 - loss: 0.0620 - val_custom_metric: 0.1790 - val_loss: 0.0644
# Epoch 17/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.1938 - loss: 0.0505 - val_custom_metric: 0.2050 - val_loss: 0.0482
# Epoch 18/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.2267 - loss: 0.0442 - val_custom_metric: 0.2363 - val_loss: 0.0330
# Epoch 19/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.2615 - loss: 0.0288 - val_custom_metric: 0.2704 - val_loss: 0.0222
# Epoch 20/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.2940 - loss: 0.0189 - val_custom_metric: 0.3006 - val_loss: 0.0161
# Epoch 21/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3175 - loss: 0.0142 - val_custom_metric: 0.3190 - val_loss: 0.0124
# Epoch 22/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3360 - loss: 0.0125 - val_custom_metric: 0.3201 - val_loss: 0.0104
# Epoch 23/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3238 - loss: 0.0115 - val_custom_metric: 0.3141 - val_loss: 0.0097
# Epoch 24/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3173 - loss: 0.0101 - val_custom_metric: 0.3093 - val_loss: 0.0096
# Epoch 25/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3129 - loss: 0.0088 - val_custom_metric: 0.3175 - val_loss: 0.0080
# Epoch 26/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3150 - loss: 0.0076 - val_custom_metric: 0.3252 - val_loss: 0.0069
# Epoch 27/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3333 - loss: 0.0078 - val_custom_metric: 0.3264 - val_loss: 0.0063
# Epoch 28/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3252 - loss: 0.0066 - val_custom_metric: 0.3237 - val_loss: 0.0063
# Epoch 29/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3302 - loss: 0.0065 - val_custom_metric: 0.3254 - val_loss: 0.0058
# Epoch 30/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3199 - loss: 0.0057 - val_custom_metric: 0.3301 - val_loss: 0.0051
# Epoch 31/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3228 - loss: 0.0053 - val_custom_metric: 0.3301 - val_loss: 0.0049
# Epoch 32/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3282 - loss: 0.0050 - val_custom_metric: 0.3302 - val_loss: 0.0047
# Epoch 33/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3223 - loss: 0.0046 - val_custom_metric: 0.3335 - val_loss: 0.0043
# Epoch 34/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3408 - loss: 0.0043 - val_custom_metric: 0.3363 - val_loss: 0.0039
# Epoch 35/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_metric: 0.3337 - loss: 0.0042 - val_custom_metric: 0.3350 - val_loss: 0.0039
# Epoch 36/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3339 - loss: 0.0039 - val_custom_metric: 0.3350 - val_loss: 0.0038
# Epoch 37/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3326 - loss: 0.0038 - val_custom_metric: 0.3376 - val_loss: 0.0036
# Epoch 38/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3352 - loss: 0.0039 - val_custom_metric: 0.3387 - val_loss: 0.0034
# Epoch 39/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3305 - loss: 0.0034 - val_custom_metric: 0.3384 - val_loss: 0.0033
# Epoch 40/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3336 - loss: 0.0035 - val_custom_metric: 0.3391 - val_loss: 0.0032
# Epoch 41/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3318 - loss: 0.0033 - val_custom_metric: 0.3415 - val_loss: 0.0030
# Epoch 42/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3382 - loss: 0.0033 - val_custom_metric: 0.3398 - val_loss: 0.0030
# Epoch 43/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3307 - loss: 0.0031 - val_custom_metric: 0.3412 - val_loss: 0.0028
# Epoch 44/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_metric: 0.3350 - loss: 0.0028 - val_custom_metric: 0.3424 - val_loss: 0.0027
# Epoch 45/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_metric: 0.3340 - loss: 0.0026 - val_custom_metric: 0.3422 - val_loss: 0.0027
# Epoch 46/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3312 - loss: 0.0029 - val_custom_metric: 0.3426 - val_loss: 0.0026
# Epoch 47/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3390 - loss: 0.0026 - val_custom_metric: 0.3433 - val_loss: 0.0025
# Epoch 48/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3332 - loss: 0.0026 - val_custom_metric: 0.3430 - val_loss: 0.0025
# Epoch 49/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3442 - loss: 0.0027 - val_custom_metric: 0.3437 - val_loss: 0.0024
# Epoch 50/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3331 - loss: 0.0023 - val_custom_metric: 0.3454 - val_loss: 0.0023
# Epoch 51/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3397 - loss: 0.0024 - val_custom_metric: 0.3446 - val_loss: 0.0023
# Epoch 52/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3371 - loss: 0.0023 - val_custom_metric: 0.3443 - val_loss: 0.0023
# Epoch 53/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3427 - loss: 0.0025 - val_custom_metric: 0.3461 - val_loss: 0.0022
# Epoch 54/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3368 - loss: 0.0023 - val_custom_metric: 0.3460 - val_loss: 0.0022
# Epoch 55/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3354 - loss: 0.0023 - val_custom_metric: 0.3454 - val_loss: 0.0021
# Epoch 56/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3304 - loss: 0.0022 - val_custom_metric: 0.3472 - val_loss: 0.0021
# Epoch 57/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3352 - loss: 0.0022 - val_custom_metric: 0.3483 - val_loss: 0.0020
# Epoch 58/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3447 - loss: 0.0023 - val_custom_metric: 0.3467 - val_loss: 0.0020
# Epoch 59/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3391 - loss: 0.0023 - val_custom_metric: 0.3482 - val_loss: 0.0019
# Epoch 60/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3346 - loss: 0.0021 - val_custom_metric: 0.3487 - val_loss: 0.0019
# Epoch 61/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - custom_metric: 0.3402 - loss: 0.0021 - val_custom_metric: 0.3487 - val_loss: 0.0018
# Epoch 62/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3301 - loss: 0.0017 - val_custom_metric: 0.3489 - val_loss: 0.0018
# Epoch 63/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3366 - loss: 0.0019 - val_custom_metric: 0.3492 - val_loss: 0.0018
# Epoch 64/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3378 - loss: 0.0018 - val_custom_metric: 0.3494 - val_loss: 0.0018
# Epoch 65/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_metric: 0.3397 - loss: 0.0018 - val_custom_metric: 0.3493 - val_loss: 0.0018
# Epoch 66/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3390 - loss: 0.0019 - val_custom_metric: 0.3501 - val_loss: 0.0017
# Epoch 67/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3365 - loss: 0.0018 - val_custom_metric: 0.3511 - val_loss: 0.0017
# Epoch 68/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3380 - loss: 0.0016 - val_custom_metric: 0.3504 - val_loss: 0.0017
# Epoch 69/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3360 - loss: 0.0017 - val_custom_metric: 0.3510 - val_loss: 0.0016
# Epoch 70/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3431 - loss: 0.0018 - val_custom_metric: 0.3515 - val_loss: 0.0017
# Epoch 71/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3467 - loss: 0.0016 - val_custom_metric: 0.3513 - val_loss: 0.0017
# Epoch 72/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3341 - loss: 0.0014 - val_custom_metric: 0.3517 - val_loss: 0.0017
# Epoch 73/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3390 - loss: 0.0016 - val_custom_metric: 0.3524 - val_loss: 0.0017
# Epoch 74/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3351 - loss: 0.0014 - val_custom_metric: 0.3531 - val_loss: 0.0017
# Epoch 75/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3411 - loss: 0.0013 - val_custom_metric: 0.3524 - val_loss: 0.0017
# Epoch 76/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3406 - loss: 0.0014 - val_custom_metric: 0.3529 - val_loss: 0.0016
# Epoch 77/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3386 - loss: 0.0013 - val_custom_metric: 0.3526 - val_loss: 0.0016
# Epoch 78/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3501 - loss: 0.0015 - val_custom_metric: 0.3546 - val_loss: 0.0016
# Epoch 79/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3427 - loss: 0.0013 - val_custom_metric: 0.3528 - val_loss: 0.0016
# Epoch 80/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3317 - loss: 0.0014 - val_custom_metric: 0.3546 - val_loss: 0.0016
# Epoch 81/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3394 - loss: 0.0012 - val_custom_metric: 0.3527 - val_loss: 0.0016
# Epoch 82/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3375 - loss: 0.0012 - val_custom_metric: 0.3539 - val_loss: 0.0015
# Epoch 83/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3332 - loss: 0.0012 - val_custom_metric: 0.3542 - val_loss: 0.0015
# Epoch 84/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3416 - loss: 0.0011 - val_custom_metric: 0.3540 - val_loss: 0.0015
# Epoch 85/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_metric: 0.3471 - loss: 0.0012 - val_custom_metric: 0.3551 - val_loss: 0.0014
# Epoch 86/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3444 - loss: 0.0011 - val_custom_metric: 0.3545 - val_loss: 0.0015
# Epoch 87/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - custom_metric: 0.3454 - loss: 0.0011 - val_custom_metric: 0.3548 - val_loss: 0.0014
# Epoch 88/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3453 - loss: 0.0011 - val_custom_metric: 0.3544 - val_loss: 0.0014
# Epoch 89/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3488 - loss: 0.0011 - val_custom_metric: 0.3555 - val_loss: 0.0014
# Epoch 90/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_metric: 0.3370 - loss: 0.0011 - val_custom_metric: 0.3550 - val_loss: 0.0014
# Epoch 91/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_metric: 0.3463 - loss: 0.0010 - val_custom_metric: 0.3557 - val_loss: 0.0014
# Epoch 92/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_metric: 0.3397 - loss: 0.0010 - val_custom_metric: 0.3549 - val_loss: 0.0014
# Epoch 93/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3425 - loss: 0.0010 - val_custom_metric: 0.3560 - val_loss: 0.0014
# Epoch 94/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3438 - loss: 9.9540e-04 - val_custom_metric: 0.3562 - val_loss: 0.0013
# Epoch 95/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - custom_metric: 0.3394 - loss: 9.7228e-04 - val_custom_metric: 0.3554 - val_loss: 0.0013
# Epoch 96/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3457 - loss: 0.0011 - val_custom_metric: 0.3566 - val_loss: 0.0013
# Epoch 97/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3425 - loss: 9.6973e-04 - val_custom_metric: 0.3543 - val_loss: 0.0013
# Epoch 98/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3382 - loss: 9.8268e-04 - val_custom_metric: 0.3566 - val_loss: 0.0013
# Epoch 99/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3460 - loss: 0.0010 - val_custom_metric: 0.3557 - val_loss: 0.0013
# Epoch 100/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_metric: 0.3466 - loss: 0.0010 - val_custom_metric: 0.3562 - val_loss: 0.0012
# Epoch 101/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - custom_metric: 0.3448 - loss: 0.0010 - val_custom_metric: 0.3577 - val_loss: 0.0012
# Epoch 102/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_metric: 0.3408 - loss: 9.1679e-04 - val_custom_metric: 0.3548 - val_loss: 0.0012
# Epoch 103/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_metric: 0.3473 - loss: 9.6905e-04 - val_custom_metric: 0.3573 - val_loss: 0.0012
# Epoch 104/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3485 - loss: 9.1223e-04 - val_custom_metric: 0.3543 - val_loss: 0.0012
# Epoch 105/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_metric: 0.3457 - loss: 9.1604e-04 - val_custom_metric: 0.3566 - val_loss: 0.0011
# Epoch 106/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3524 - loss: 9.0522e-04 - val_custom_metric: 0.3555 - val_loss: 0.0012
# Epoch 107/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3450 - loss: 8.9309e-04 - val_custom_metric: 0.3570 - val_loss: 0.0011
# Epoch 108/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3494 - loss: 8.7699e-04 - val_custom_metric: 0.3569 - val_loss: 0.0011
# Epoch 109/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_metric: 0.3493 - loss: 8.8261e-04 - val_custom_metric: 0.3569 - val_loss: 0.0011
# Epoch 110/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3472 - loss: 8.6800e-04 - val_custom_metric: 0.3560 - val_loss: 0.0011
# Epoch 111/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3401 - loss: 8.1461e-04 - val_custom_metric: 0.3570 - val_loss: 0.0010
# Epoch 112/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3452 - loss: 7.9742e-04 - val_custom_metric: 0.3566 - val_loss: 0.0010
# Epoch 113/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3458 - loss: 7.9791e-04 - val_custom_metric: 0.3571 - val_loss: 0.0010
# Epoch 114/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3506 - loss: 7.9979e-04 - val_custom_metric: 0.3571 - val_loss: 9.9296e-04
# Epoch 115/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3455 - loss: 7.8787e-04 - val_custom_metric: 0.3573 - val_loss: 9.9070e-04
# Epoch 116/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3431 - loss: 7.3275e-04 - val_custom_metric: 0.3575 - val_loss: 9.5721e-04
# Epoch 117/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3416 - loss: 7.5592e-04 - val_custom_metric: 0.3571 - val_loss: 9.7608e-04
# Epoch 118/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3440 - loss: 7.6419e-04 - val_custom_metric: 0.3585 - val_loss: 9.4346e-04
# Epoch 119/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3481 - loss: 7.6516e-04 - val_custom_metric: 0.3563 - val_loss: 9.7212e-04
# Epoch 120/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3435 - loss: 7.5908e-04 - val_custom_metric: 0.3589 - val_loss: 8.9953e-04
# Epoch 121/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - custom_metric: 0.3413 - loss: 8.1318e-04 - val_custom_metric: 0.3556 - val_loss: 9.6370e-04
# Epoch 122/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3459 - loss: 7.5441e-04 - val_custom_metric: 0.3587 - val_loss: 8.7957e-04
# Epoch 123/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3441 - loss: 7.7591e-04 - val_custom_metric: 0.3563 - val_loss: 9.3954e-04
# Epoch 124/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3540 - loss: 7.6064e-04 - val_custom_metric: 0.3589 - val_loss: 8.6956e-04
# Epoch 125/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3475 - loss: 7.5616e-04 - val_custom_metric: 0.3566 - val_loss: 9.1609e-04
# Epoch 126/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3483 - loss: 7.3459e-04 - val_custom_metric: 0.3574 - val_loss: 8.8566e-04
# Epoch 127/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3490 - loss: 7.2182e-04 - val_custom_metric: 0.3590 - val_loss: 8.5630e-04
# Epoch 128/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3514 - loss: 7.6764e-04 - val_custom_metric: 0.3571 - val_loss: 8.8899e-04
# Epoch 129/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3398 - loss: 6.9616e-04 - val_custom_metric: 0.3591 - val_loss: 8.2914e-04
# Epoch 130/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3413 - loss: 6.8528e-04 - val_custom_metric: 0.3561 - val_loss: 8.9930e-04
# Epoch 131/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3400 - loss: 7.3599e-04 - val_custom_metric: 0.3582 - val_loss: 8.1693e-04
# Epoch 132/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3435 - loss: 6.5624e-04 - val_custom_metric: 0.3571 - val_loss: 8.4136e-04
# Epoch 133/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - custom_metric: 0.3400 - loss: 6.7719e-04 - val_custom_metric: 0.3589 - val_loss: 7.9075e-04
# Epoch 134/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3518 - loss: 7.0529e-04 - val_custom_metric: 0.3574 - val_loss: 8.1532e-04
# Epoch 135/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3481 - loss: 7.0133e-04 - val_custom_metric: 0.3590 - val_loss: 7.8703e-04
# Epoch 136/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3408 - loss: 7.2131e-04 - val_custom_metric: 0.3577 - val_loss: 7.9462e-04
# Epoch 137/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3491 - loss: 6.5758e-04 - val_custom_metric: 0.3586 - val_loss: 7.8242e-04
# Epoch 138/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - custom_metric: 0.3450 - loss: 6.2583e-04 - val_custom_metric: 0.3585 - val_loss: 7.6848e-04
# Epoch 139/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3492 - loss: 6.2290e-04 - val_custom_metric: 0.3584 - val_loss: 7.6751e-04
# Epoch 140/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3426 - loss: 6.1601e-04 - val_custom_metric: 0.3571 - val_loss: 7.8995e-04
# Epoch 141/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_metric: 0.3537 - loss: 7.1085e-04 - val_custom_metric: 0.3597 - val_loss: 7.3505e-04
# Epoch 142/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3448 - loss: 6.8640e-04 - val_custom_metric: 0.3580 - val_loss: 7.6847e-04
# Epoch 143/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3406 - loss: 6.5178e-04 - val_custom_metric: 0.3585 - val_loss: 7.6382e-04
# Epoch 144/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3505 - loss: 6.2529e-04 - val_custom_metric: 0.3580 - val_loss: 7.6305e-04
# Epoch 145/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3429 - loss: 6.2511e-04 - val_custom_metric: 0.3595 - val_loss: 7.3794e-04
# Epoch 146/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - custom_metric: 0.3444 - loss: 6.5410e-04 - val_custom_metric: 0.3569 - val_loss: 7.7925e-04
# Epoch 147/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - custom_metric: 0.3509 - loss: 6.6181e-04 - val_custom_metric: 0.3594 - val_loss: 7.1011e-04
# Epoch 148/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3422 - loss: 6.3655e-04 - val_custom_metric: 0.3586 - val_loss: 7.1271e-04
# Epoch 149/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_metric: 0.3464 - loss: 5.9156e-04 - val_custom_metric: 0.3577 - val_loss: 7.2979e-04
# Epoch 150/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_metric: 0.3453 - loss: 6.2867e-04 - val_custom_metric: 0.3588 - val_loss: 7.1241e-04

# %%
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Pérdida del modelo a lo largo de las épocas')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# %%
plt.plot(history.history['custom_metric'], label='Métrica de entrenamiento')
plt.plot(history.history['val_custom_metric'], label='Métrica de validación')
plt.title('Métrica del modelo a lo largo de las épocas')
plt.xlabel('Época')
plt.ylabel('Métrica')
plt.legend()
plt.show()

# %%
# Evaluar el modelo con los datos de prueba
test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f'Pérdida en el conjunto de prueba: {test_loss}')

# Hacer predicciones con los datos de prueba
y_pred = model.predict(X_test)
# Out:
# Pérdida en el conjunto de prueba: [0.0007124101393856108, 0.3587994873523712]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
def modelo_pseudo_n(t, qe, k):
    return qe * (1 - np.exp(- k * t))

n=np.random.randint(0,len(y_test))

q_t_pred = modelo_pseudo_n(time_array, y_pred[n][0], y_pred[n][1])
plt.plot(time_array, q_t_pred)
plt.scatter(time_array, y_test[n], color='red')
print(n)
# Out:
# 12

# %%
model.save('Modelo_200samples.keras')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test[0], q_t_pred)  # Graficar los puntos
plt.xlabel('y_real (Valores reales)')
plt.ylabel('y_pred (Predicciones)')
plt.title('Gráfico de dispersión: y_real vs. y_pred')
plt.plot([min(y_test.flatten()), max(y_test.flatten())], [min(y_test.flatten()), max(y_test.flatten())], color='red', linestyle='--') #Linea de referencia
plt.grid(True)
plt.show()

# %%
import pandas as pd
df_exp = pd.read_excel('Datos recogidos.xlsx')
df_exp
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-48a6df099d1e> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df_exp = pd.read_excel('Datos recogidos.xlsx')
#       3 df_exp
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548                 ext = "xls"
#    1549             else:
# -> 1550                 ext = inspect_excel_format(
#    1551                     content_or_path=path_or_buffer, storage_options=storage_options
#    1552                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1400         content_or_path = BytesIO(content_or_path)
#    1401
# -> 1402     with get_handle(
#    1403         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Datos recogidos.xlsx'

# %%
df_exp = pd.read_excel('Datos recogidos.xlsx')
df_exp['T0'] = np.zeros(len(df_exp))
df_tiempos = df_exp[['T0', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6 ','T7 ','T8']]
df_tiempos

# %%
df_exp = pd.read_excel('Datos recogidos.xlsx')
for i in range(len(df_exp)):
  data_exp = df_exp.iloc[i].iloc[2::]
  time_array = np.array([1,3,6,9,12,20,40,60])
  plt.plot(time_array,data_exp)

# %%
df_exp['T0'] = np.zeros(len(df_exp))
df_tiempos = df_exp[['T0', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6 ','T7 ']]

# %%
np.array(df_tiempos.iloc[3])

# %%
for i in range(len(df_tiempos)):
  data_exp = np.array(df_tiempos.iloc[i])
  time_array = np.array([0,1,3,6,9,12,20,40,60])
  plt.plot(time_array,data_exp)

# %%
data_exp = np.array(df_tiempos.iloc[1])
